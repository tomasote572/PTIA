# %%
# @title Importando Librerías
import pandas as pd

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1BA8IP2VsCZAQ2MMxq1twrindVGMU7JHe4Qrdn-8N9Oc/export?format=csv&gid=2056133412")

# %%
df.sample(10)
# Out:
#                Nombre  Edad  Peso  Altura  Genero
# 0      Roberto Alfaro    19    70    1.78  Hombre
# 17  Francisco  Huerta    21    71    1.75  Hombre
# 1    Laura Bustamante    19    57    1.60   Mujer
# 20     Tania Alvarado    24    70    1.70   Mujer
# 13       Lily Ramírez    23    55    1.50   Mujer
# 15     Paulina Flores    21    66    1.78   Mujer
# 11        Elena Pérez    24    59    1.61   Mujer
# 14        Roxana Cruz    20    50    1.56   Mujer
# 6    Adolfo Hernández    22    70    1.73  Hombre
# 19      Sofia Padilla    18    69    1.70   Mujer

# %%
df.Edad.value_counts()
# Out:
# 21    6
# 23    4
# 20    4
# 19    4
# 24    3
# 25    2
# 22    1
# 18    1
# Name: Edad, dtype: int64

# %% [markdown]
# # Cantidad

# %% [markdown]
# # Gráficas de proporción
#
# Funcionan bien cuando, agrupamos, agregamos.
#
# Count ->
# Sum ->
# min ->
#
# * Pie
# * Barras

# %%
# @title Gráfica de pastel 

df_genero: pd.Series = df.Genero.value_counts()
display(df_genero)
df_genero.plot.pie(autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-e47272155dea> in <module>()
#       1 # @title Gráfica de pastel
#       2
# ----> 3 df_genero: pd.Series = df.Genero.value_counts()
#       4 display(df_genero)
#       5 df_genero.plot.pie(autopct='%1%%')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Genero'

# %%
df = pd.DataFrame([{"genero":"Hombre", "Cantidad": 12},{"genero":"Mujer", "Cantidad": 12} ])
df
# Out:
#    genero  Cantidad
# 0  Hombre        12
# 1   Mujer        12

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97], 'radius': [2439.7, 6051.8, 6378.1]}, index=['Mercury', 'Venus', 'Earth'])
display(df)

plot = df.plot.pie(y='mass', figsize=(5, 5))
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
df_genero.plot.barh()

# %%
edad = df.Edad.value_counts()
edad = edad.sort_index()
edad.plot.barh()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-fd70a0aea738> in <module>()
# ----> 1 edad = df.Edad.value_counts()
#       2 edad = edad.sort_index()
#       3 edad.plot.barh()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Edad'

# %% [markdown]
# # Distribución
# * Histograma
# * Caja
# * Densidad

# %%
df.Altura.plot.kde()

# %%
df.Altura.plot.box()

# %%
df.Altura.plot.hist(bins=8)

# %%
edad.sort_index()
# Out:
# 18    1
# 19    4
# 20    4
# 21    6
# 22    1
# 23    4
# 24    3
# 25    2
# Name: Edad, dtype: int64

# %%
df.plot.hist(by="Edad", bins=5)

# %%
df.plot.scatter("Altura","Peso")

# %%
df.sort_values("Peso").plot.line("Peso", "Altura")

# %%
# Ejemplo real para la de area
df = pd.DataFrame(np.random.rand(4, 4) * 1000, columns=['2017', '2018', '2019', '2020'])
df.plot.area(stacked=False)

# %%
df.index=[1,2,3,4]
df
df.plot.line()

# %%
df.plot.hexbin("Peso","Altura")

# %%
df.plot.

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar();
# Out:
#           a         b         c         d
# 0  0.168583  0.499245  0.726565  0.372691
# 1  0.029609  0.268443  0.793344  0.301814
# 2  0.193021  0.996373  0.532913  0.130441
# 3  0.059831  0.387409  0.011405  0.260725
# 4  0.847446  0.895668  0.260810  0.120306
# 5  0.301448  0.937790  0.629943  0.361221
# 6  0.534208  0.790671  0.473252  0.300755
# 7  0.861845  0.369913  0.494989  0.733390
# 8  0.905071  0.776443  0.938049  0.471776
# 9  0.991929  0.562718  0.975469  0.234795

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df4
# Out:
#             a         b         c
# 0    0.244968 -0.226918 -1.319732
# 1   -1.497604 -0.208458  0.123712
# 2   -0.015586 -0.091691  0.313712
# 3    2.643529 -0.969151 -0.556419
# 4    1.723620 -1.188803 -0.948805
# ..        ...       ...       ...
# 995  0.432505  0.956643 -1.829926
# 996  1.472183  0.928944 -0.463998
# 997  2.641477 -0.262370 -0.242519
# 998  2.383506  0.463191 -2.491668
# 999 -1.351888  1.851030 -1.446887
#
# [1000 rows x 3 columns]
